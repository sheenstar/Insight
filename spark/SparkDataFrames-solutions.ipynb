# %%
from pyspark.sql.types import *
from pyspark.sql import Row
from time import time

# %% [markdown]
# # Introduction
#
# Spark has the conceptual equivalent of R and pandas dataframes available through the DataFrames API. In Spark DataFrames may be created from existing RDDs, structured data files, external databases, or tables in Hive, etc. These DataFrames allow for the manipulation of distributed data through operations such as filter, groupby, and join, which are automatically optimized through parallelization and distribution across clusters when an action triggers the job.
#
# We are going to use the dating profiles dataset for this tutorial. More information on this dataset can be found [here](https://sites.google.com/a/insightdatascience.com/spark-lab/s3-data/dating-profiles).

# %% [markdown]
# # Loading in the data
# First, read in the data into an RDD. Here, we are using 16 partitions for our RDD.

# %%
# Read in raw ratings data (fromUserId, toUserId, rating)
ratingsCsvRDD = sc.textFile("s3a://insight-spark-after-dark/ratings.csv.gz").repartition(12)

# %% [markdown]
# Reformat the data into a JSON format by applying the function rec_tup (which converts the data into a JSON format) to the RDD using the .map and .toDF() transformation steps.

# %%
# Convert raw ratings RDD to Json RDD
def rec_tup(rating):
    tokens = rating.split(",")
    return Row(fromUserId=int(tokens[0]), toUserId=int(tokens[1]), rating=int(tokens[2]))

ratingsJson_DF = ratingsCsvRDD.map(rec_tup).toDF()
ratingsJson_DF.take(5)
# Out:
# [Row(fromUserId=1, rating=5, toUserId=4842),
#  Row(fromUserId=1, rating=4, toUserId=12638),
#  Row(fromUserId=1, rating=10, toUserId=18345),
#  Row(fromUserId=1, rating=10, toUserId=22319),
#  Row(fromUserId=1, rating=10, toUserId=26084)]

# %% [markdown]
# As you might remember, Spark does a Lazy evaluation which means each transformed RDD may be recomputed each time you run an action on it. We'll use the .persist method (this is actually also a transformation) to keep the result (transformed RDD) on the cluster for quick future access.
#
# **Note**: persist is a transformation, it will only run when a future action is called. One result of this is that if you run an action twice, you will persist twice (and right now in Spark you will lose the pointer to the first persist).

# %%
# Cache the SchemaRDD as we'll be using this heavily moving forward
ratingsJson_DF.persist(StorageLevel.MEMORY_AND_DISK_SER)
# Out:
# DataFrame[fromUserId: bigint, rating: bigint, toUserId: bigint]

# %% [markdown]
# Quickly check the schema of the dataframe.
# To write SparkSQL, we need to create a table object from our dataframe which we can use to run SparkSQL commands. The transformation registerTempTable() does this and we call our table 'ratingsJsonTable'.

# %%
# Describe the SchemaRDD inferred from the JSON
ratingsJson_DF.printSchema()
# Out:
# root
#  |-- fromUserId: long (nullable = true)
#  |-- rating: long (nullable = true)
#  |-- toUserId: long (nullable = true)

# %% [markdown]
# # On to Spark DataFrames

# %% [markdown]
# Spark DataFrames is an abstract API that lets you perform Pandas or R like commands to your dataset.

# %%
# Show the top 10 most-active users who are giving out ratings
mostActiveUsersSchemaDF = ratingsJson_DF.select("fromUserId","toUserId")\
                                        .groupBy("fromUserId")\
                                        .count()\
                                        .withColumnRenamed("count", "num_ratings")\
                                        .orderBy(["num_ratings"], ascending=[0])
mostActiveUsersSchemaDF.take(10)
# Out:
# [Row(fromUserId=90280, num_ratings=25042),
#  Row(fromUserId=56792, num_ratings=21599),
#  Row(fromUserId=33639, num_ratings=19908),
#  Row(fromUserId=61436, num_ratings=18810),
#  Row(fromUserId=72351, num_ratings=18443),
#  Row(fromUserId=127227, num_ratings=18342),
#  Row(fromUserId=58765, num_ratings=18197),
#  Row(fromUserId=76082, num_ratings=18019),
#  Row(fromUserId=108318, num_ratings=17755),
#  Row(fromUserId=131976, num_ratings=17560)]

# %% [markdown]
# # Sampling
# We can also sample the dataframe with the sample() transformation. Great way to test the job before running on the full dataset.
#
# Sample takes 3 arguments: **oversample (True/False), fraction of data in sample, seed**

# %%
ratingsJson_DF.sample(False, 0.1, 20).collect()
# Out:
# [Row(fromUserId=1, rating=1, toUserId=82536),
#  Row(fromUserId=1, rating=10, toUserId=98556),
#  Row(fromUserId=1, rating=10, toUserId=138830),
#  Row(fromUserId=2, rating=9, toUserId=196265),
#  Row(fromUserId=3, rating=7, toUserId=15530),
#  Row(fromUserId=5, rating=9, toUserId=94074),
#  Row(fromUserId=7, rating=7, toUserId=213803),
#  Row(fromUserId=9, rating=10, toUserId=15629),
#  Row(fromUserId=9, rating=9, toUserId=20960),
#  Row(fromUserId=9, rating=10, toUserId=27136),
#  Row(fromUserId=9, rating=10, toUserId=31890),
#  Row(fromUserId=9, rating=10, toUserId=32177),
#  Row(fromUserId=9, rating=7, toUserId=33822),
#  Row(fromUserId=9, rating=6, toUserId=39420),
#  Row(fromUserId=9, rating=10, toUserId=39994),
#  Row(fromUserId=9, rating=4, toUserId=59330),
#  Row(fromUserId=9, rating=6, toUserId=64805),
#  Row(fromUserId=9, rating=1, toUserId=65906),
#  Row(fromUserId=9, rating=1, toUserId=70018),
#  Row(fromUserId=9, rating=10, toUserId=70420),
#  Row(fromUserId=9, rating=2, toUserId=72611),
#  Row(fromUserId=9, rating=7, toUserId=82728),
#  Row(fromUserId=9, rating=2, toUserId=84562),
#  Row(fromUserId=9, rating=1, toUserId=85283),
#  Row(fromUserId=9, rating=10, toUserId=89572),
#  Row(fromUserId=9, rating=10, toUserId=95950),
#  Row(fromUserId=9, rating=7, toUserId=104377),
#  Row(fromUserId=9, rating=7, toUserId=114852),
#  Row(fromUserId=9, rating=6, toUserId=119744),
#  Row(fromUserId=9, rating=10, toUserId=123026),
#  Row(fromUserId=9, rating=1, toUserId=127262),
#  Row(fromUserId=9, rating=9, toUserId=132437),
#  Row(fromUserId=9, rating=5, toUserId=135270),
#  Row(fromUserId=9, rating=1, toUserId=142470),
#  Row(fromUserId=9, rating=4, toUserId=168706),
#  Row(fromUserId=9, rating=4, toUserId=172366),
#  Row(fromUserId=9, rating=1, toUserId=177020),
#  Row(fromUserId=9, rating=8, toUserId=205562),
#  Row(fromUserId=9, rating=8, toUserId=209724),
#  Row(fromUserId=9, rating=8, toUserId=213587),
#  Row(fromUserId=10, rating=10, toUserId=58395),
#  Row(fromUserId=11, rating=9, toUserId=12006),
#  Row(fromUserId=14, rating=10, toUserId=36312),
#  Row(fromUserId=15, rating=10, toUserId=77),
#  Row(fromUserId=15, rating=8, toUserId=46763),
#  Row(fromUserId=17, rating=5, toUserId=65854),
#  Row(fromUserId=17, rating=1, toUserId=137252),
#  Row(fromUserId=18, rating=8, toUserId=12160),
#  Row(fromUserId=18, rating=10, toUserId=34631),
#  Row(fromUserId=18, rating=10, toUserId=45385),
#  Row(fromUserId=18, rating=2, toUserId=218923),
#  Row(fromUserId=19, rating=7, toUserId=160120),
#  Row(fromUserId=20, rating=5, toUserId=208459),
#  Row(fromUserId=26, rating=5, toUserId=50408),
#  Row(fromUserId=28, rating=2, toUserId=15812),
#  Row(fromUserId=30, rating=10, toUserId=101455),
#  Row(fromUserId=31, rating=10, toUserId=6932),
#  Row(fromUserId=31, rating=10, toUserId=13346),
#  Row(fromUserId=31, rating=5, toUserId=82141),
#  Row(fromUserId=31, rating=1, toUserId=102478),
#  Row(fromUserId=31, rating=4, toUserId=134581),
#  Row(fromUserId=34, rating=6, toUserId=100449),
#  Row(fromUserId=35, rating=7, toUserId=93172),
#  Row(fromUserId=36, rating=10, toUserId=10399),
#  Row(fromUserId=36, rating=10, toUserId=116895),
#  Row(fromUserId=38, rating=6, toUserId=174724),
#  Row(fromUserId=39, rating=10, toUserId=35647),
#  Row(fromUserId=39, rating=8, toUserId=194807),
#  Row(fromUserId=40, rating=7, toUserId=6437),
#  Row(fromUserId=42, rating=10, toUserId=36793),
#  Row(fromUserId=47, rating=6, toUserId=74816),
#  Row(fromUserId=48, rating=3, toUserId=46193),
#  Row(fromUserId=50, rating=3, toUserId=33754),
#  Row(fromUserId=50, rating=8, toUserId=102474),
#  Row(fromUserId=55, rating=3, toUserId=1633),
#  Row(fromUserId=58, rating=8, toUserId=6036),
#  Row(fromUserId=58, rating=7, toUserId=90184),
#  Row(fromUserId=58, rating=5, toUserId=219708),
#  Row(fromUserId=59, rating=10, toUserId=12107),
#  Row(fromUserId=59, rating=10, toUserId=46687),
#  Row(fromUserId=60, rating=10, toUserId=35553),
#  Row(fromUserId=60, rating=1, toUserId=125965),
#  Row(fromUserId=60, rating=4, toUserId=133868),
#  Row(fromUserId=60, rating=7, toUserId=173600),
#  Row(fromUserId=63, rating=7, toUserId=100709),
#  Row(fromUserId=64, rating=7, toUserId=193687),
#  Row(fromUserId=67, rating=7, toUserId=194553),
#  Row(fromUserId=68, rating=10, toUserId=61157),
#  Row(fromUserId=68, rating=5, toUserId=211156),
#  Row(fromUserId=73, rating=5, toUserId=7443),
#  Row(fromUserId=73, rating=5, toUserId=34168),
#  Row(fromUserId=73, rating=5, toUserId=60183),
#  Row(fromUserId=73, rating=10, toUserId=72744),
#  Row(fromUserId=73, rating=7, toUserId=97218),
#  Row(fromUserId=73, rating=7, toUserId=105133),
#  Row(fromUserId=73, rating=7, toUserId=109438),
#  Row(fromUserId=73, rating=9, toUserId=122919),
#  Row(fromUserId=73, rating=10, toUserId=174969),
#  Row(fromUserId=73, rating=8, toUserId=196094),
#  Row(fromUserId=73, rating=8, toUserId=203563),
#  Row(fromUserId=73, rating=8, toUserId=211864),
#  Row(fromUserId=74, rating=3, toUserId=36108),
#  Row(fromUserId=74, rating=1, toUserId=78596),
#  Row(fromUserId=82, rating=6, toUserId=128057),
#  Row(fromUserId=83, rating=2, toUserId=31336),
#  Row(fromUserId=85, rating=9, toUserId=63228),
#  Row(fromUserId=86, rating=6, toUserId=72051),
#  Row(fromUserId=86, rating=3, toUserId=196806),
#  Row(fromUserId=87, rating=10, toUserId=34219),
#  Row(fromUserId=87, rating=8, toUserId=86124),
#  Row(fromUserId=88, rating=2, toUserId=63373),
#  Row(fromUserId=88, rating=6, toUserId=169692),
#  Row(fromUserId=90, rating=5, toUserId=18357),
#  Row(fromUserId=90, rating=10, toUserId=84151),
#  Row(fromUserId=90, rating=6, toUserId=170689),
#  Row(fromUserId=90, rating=10, toUserId=186640),
#  Row(fromUserId=92, rating=4, toUserId=137241),
#  Row(fromUserId=94, rating=10, toUserId=45330),
#  Row(fromUserId=98, rating=5, toUserId=73259),
#  Row(fromUserId=99, rating=7, toUserId=33386),
#  Row(fromUserId=99, rating=9, toUserId=66990),
#  Row(fromUserId=99, rating=10, toUserId=71636),
#  Row(fromUserId=99, rating=10, toUserId=90195),
#  Row(fromUserId=99, rating=4, toUserId=99667),
#  Row(fromUserId=99, rating=6, toUserId=124174),
#  Row(fromUserId=99, rating=1, toUserId=181350),
#  Row(fromUserId=99, rating=3, toUserId=215294),
#  Row(fromUserId=101, rating=7, toUserId=117780),
#  Row(fromUserId=104, rating=10, toUserId=58425),
#  Row(fromUserId=104, rating=7, toUserId=78083),
#  Row(fromUserId=104, rating=1, toUserId=99812),
#  Row(fromUserId=104, rating=4, toUserId=130926),
#  Row(fromUserId=104, rating=1, toUserId=154054),
#  Row(fromUserId=105, rating=5, toUserId=16333),
#  Row(fromUserId=105, rating=5, toUserId=47612),
#  Row(fromUserId=105, rating=10, toUserId=68760),
#  Row(fromUserId=105, rating=8, toUserId=85932),
#  Row(fromUserId=105, rating=1, toUserId=130364),
#  Row(fromUserId=106, rating=1, toUserId=110447),
#  Row(fromUserId=106, rating=1, toUserId=188720),
#  Row(fromUserId=107, rating=5, toUserId=215349),
#  Row(fromUserId=112, rating=8, toUserId=47612),
#  Row(fromUserId=112, rating=6, toUserId=69477),
#  Row(fromUserId=112, rating=10, toUserId=193903),
#  Row(fromUserId=116, rating=5, toUserId=67003),
#  Row(fromUserId=116, rating=10, toUserId=77535),
#  Row(fromUserId=116, rating=10, toUserId=132860),
#  Row(fromUserId=117, rating=3, toUserId=129661),
#  Row(fromUserId=119, rating=4, toUserId=6756),
#  Row(fromUserId=121, rating=6, toUserId=147784),
#  Row(fromUserId=123, rating=5, toUserId=81401),
#  Row(fromUserId=127, rating=1, toUserId=164665),
#  Row(fromUserId=128, rating=5, toUserId=3577),
#  Row(fromUserId=128, rating=3, toUserId=15392),
#  Row(fromUserId=128, rating=1, toUserId=58875),
#  Row(fromUserId=128, rating=8, toUserId=99591),
#  Row(fromUserId=128, rating=1, toUserId=127787),
#  Row(fromUserId=129, rating=7, toUserId=120169),
#  Row(fromUserId=130, rating=1, toUserId=21199),
#  Row(fromUserId=131, rating=2, toUserId=191720),
#  Row(fromUserId=134, rating=10, toUserId=9171),
#  Row(fromUserId=134, rating=1, toUserId=16538),
#  Row(fromUserId=134, rating=7, toUserId=23878),
#  Row(fromUserId=134, rating=4, toUserId=26729),
#  Row(fromUserId=134, rating=1, toUserId=27637),
#  Row(fromUserId=134, rating=6, toUserId=32257),
#  Row(fromUserId=134, rating=8, toUserId=50408),
#  Row(fromUserId=134, rating=8, toUserId=50918),
#  Row(fromUserId=134, rating=4, toUserId=58486),
#  Row(fromUserId=134, rating=1, toUserId=65019),
#  Row(fromUserId=134, rating=10, toUserId=66778),
#  Row(fromUserId=134, rating=5, toUserId=93039),
#  Row(fromUserId=134, rating=7, toUserId=103939),
#  Row(fromUserId=134, rating=6, toUserId=105429),
#  Row(fromUserId=134, rating=9, toUserId=109655),
#  Row(fromUserId=134, rating=2, toUserId=110693),
#  Row(fromUserId=134, rating=7, toUserId=116024),
#  Row(fromUserId=134, rating=9, toUserId=135481),
#  Row(fromUserId=134, rating=7, toUserId=137971),
#  Row(fromUserId=134, rating=9, toUserId=138801),
#  Row(fromUserId=134, rating=2, toUserId=141653),
#  Row(fromUserId=134, rating=1, toUserId=143606),
#  Row(fromUserId=134, rating=3, toUserId=144778),
#  Row(fromUserId=134, rating=7, toUserId=150351),
#  Row(fromUserId=134, rating=8, toUserId=161620),
#  Row(fromUserId=134, rating=8, toUserId=164734),
#  Row(fromUserId=134, rating=10, toUserId=172077),
#  Row(fromUserId=134, rating=7, toUserId=175756),
#  Row(fromUserId=134, rating=10, toUserId=176710),
#  Row(fromUserId=134, rating=10, toUserId=177012),
#  Row(fromUserId=134, rating=5, toUserId=179671),
#  Row(fromUserId=134, rating=3, toUserId=181609),
#  Row(fromUserId=134, rating=8, toUserId=183201),
#  Row(fromUserId=134, rating=10, toUserId=184406),
#  Row(fromUserId=134, rating=10, toUserId=191620),
#  Row(fromUserId=134, rating=6, toUserId=200295),
#  Row(fromUserId=134, rating=10, toUserId=201267),
#  Row(fromUserId=134, rating=10, toUserId=201748),
#  Row(fromUserId=134, rating=7, toUserId=203566),
#  Row(fromUserId=134, rating=8, toUserId=205149),
#  Row(fromUserId=134, rating=5, toUserId=210395),
#  Row(fromUserId=134, rating=7, toUserId=210813),
#  Row(fromUserId=134, rating=1, toUserId=216639),
#  Row(fromUserId=135, rating=10, toUserId=110028),
#  Row(fromUserId=135, rating=6, toUserId=177268),
#  Row(fromUserId=136, rating=1, toUserId=1625),
#  Row(fromUserId=141, rating=8, toUserId=37841),
#  Row(fromUserId=141, rating=10, toUserId=87781),
#  Row(fromUserId=141, rating=9, toUserId=219948),
#  Row(fromUserId=142, rating=1, toUserId=211699),
#  Row(fromUserId=147, rating=10, toUserId=12513),
#  Row(fromUserId=147, rating=2, toUserId=29474),
#  Row(fromUserId=147, rating=6, toUserId=68989),
#  Row(fromUserId=147, rating=4, toUserId=173776),
#  Row(fromUserId=147, rating=10, toUserId=177716),
#  Row(fromUserId=150, rating=2, toUserId=68373),
#  Row(fromUserId=152, rating=6, toUserId=110441),
#  Row(fromUserId=152, rating=10, toUserId=167976),
#  Row(fromUserId=155, rating=2, toUserId=1822),
#  Row(fromUserId=155, rating=6, toUserId=53743),
#  Row(fromUserId=155, rating=6, toUserId=105429),
#  Row(fromUserId=155, rating=4, toUserId=148595),
#  Row(fromUserId=155, rating=7, toUserId=174191),
#  Row(fromUserId=155, rating=10, toUserId=176127),
#  Row(fromUserId=155, rating=8, toUserId=218235),
#  Row(fromUserId=156, rating=9, toUserId=1721),
#  Row(fromUserId=157, rating=6, toUserId=67003),
#  Row(fromUserId=158, rating=9, toUserId=66300),
#  Row(fromUserId=161, rating=3, toUserId=42900),
#  Row(fromUserId=162, rating=10, toUserId=50566),
#  Row(fromUserId=163, rating=5, toUserId=17768),
#  Row(fromUserId=164, rating=6, toUserId=125995),
#  Row(fromUserId=165, rating=6, toUserId=55408),
#  Row(fromUserId=165, rating=6, toUserId=102309),
#  Row(fromUserId=165, rating=5, toUserId=176904),
#  Row(fromUserId=166, rating=2, toUserId=169146),
#  Row(fromUserId=167, rating=9, toUserId=85407),
#  Row(fromUserId=172, rating=5, toUserId=35646),
#  Row(fromUserId=172, rating=7, toUserId=75016),
#  Row(fromUserId=175, rating=7, toUserId=10017),
#  Row(fromUserId=176, rating=5, toUserId=152830),
#  Row(fromUserId=180, rating=4, toUserId=41460),
#  Row(fromUserId=180, rating=7, toUserId=98381),
#  Row(fromUserId=181, rating=5, toUserId=93881),
#  Row(fromUserId=182, rating=6, toUserId=70983),
#  Row(fromUserId=182, rating=2, toUserId=205091),
#  Row(fromUserId=183, rating=10, toUserId=41376),
#  Row(fromUserId=183, rating=9, toUserId=96467),
#  Row(fromUserId=186, rating=10, toUserId=42490),
#  Row(fromUserId=188, rating=7, toUserId=12110),
#  Row(fromUserId=188, rating=7, toUserId=211390),
#  Row(fromUserId=191, rating=1, toUserId=43481),
#  Row(fromUserId=191, rating=5, toUserId=123512),
#  Row(fromUserId=191, rating=2, toUserId=142917),
#  Row(fromUserId=191, rating=9, toUserId=155151),
#  Row(fromUserId=191, rating=1, toUserId=194605),
#  Row(fromUserId=192, rating=8, toUserId=46473),
#  Row(fromUserId=193, rating=3, toUserId=44358),
#  Row(fromUserId=195, rating=6, toUserId=74924),
#  Row(fromUserId=195, rating=10, toUserId=124481),
#  Row(fromUserId=196, rating=3, toUserId=109482),
#  Row(fromUserId=198, rating=6, toUserId=3376),
#  Row(fromUserId=198, rating=1, toUserId=43734),
#  Row(fromUserId=198, rating=1, toUserId=78023),
#  Row(fromUserId=198, rating=1, toUserId=95606),
#  Row(fromUserId=198, rating=1, toUserId=152681),
#  Row(fromUserId=199, rating=2, toUserId=22583),
#  Row(fromUserId=199, rating=1, toUserId=126931),
#  Row(fromUserId=202, rating=1, toUserId=14841),
#  Row(fromUserId=202, rating=4, toUserId=108288),
#  Row(fromUserId=203, rating=2, toUserId=23490),
#  Row(fromUserId=203, rating=6, toUserId=64018),
#  Row(fromUserId=203, rating=3, toUserId=105804),
#  Row(fromUserId=203, rating=10, toUserId=170461),
#  Row(fromUserId=203, rating=10, toUserId=195250),
#  Row(fromUserId=204, rating=10, toUserId=907),
#  Row(fromUserId=204, rating=10, toUserId=20397),
#  Row(fromUserId=208, rating=8, toUserId=51783),
#  Row(fromUserId=210, rating=3, toUserId=181440),
#  Row(fromUserId=211, rating=10, toUserId=42926),
#  Row(fromUserId=211, rating=6, toUserId=148519),
#  Row(fromUserId=215, rating=10, toUserId=7509),
#  Row(fromUserId=215, rating=5, toUserId=23187),
#  Row(fromUserId=215, rating=5, toUserId=88265),
#  Row(fromUserId=216, rating=8, toUserId=89863),
#  Row(fromUserId=217, rating=10, toUserId=100855),
#  Row(fromUserId=227, rating=10, toUserId=189466),
#  Row(fromUserId=231, rating=10, toUserId=102751),
#  Row(fromUserId=237, rating=1, toUserId=42399),
#  Row(fromUserId=238, rating=7, toUserId=70708),
#  Row(fromUserId=238, rating=6, toUserId=104001),
#  Row(fromUserId=240, rating=10, toUserId=1501),
#  Row(fromUserId=240, rating=10, toUserId=63659),
#  Row(fromUserId=244, rating=10, toUserId=194912),
#  Row(fromUserId=245, rating=1, toUserId=16883),
#  Row(fromUserId=245, rating=3, toUserId=86424),
#  Row(fromUserId=245, rating=3, toUserId=104567),
#  Row(fromUserId=245, rating=1, toUserId=107544),
#  Row(fromUserId=245, rating=5, toUserId=210746),
#  Row(fromUserId=246, rating=10, toUserId=81541),
#  Row(fromUserId=248, rating=7, toUserId=48536),
#  Row(fromUserId=248, rating=6, toUserId=53867),
#  Row(fromUserId=248, rating=7, toUserId=63108),
#  Row(fromUserId=248, rating=8, toUserId=71136),
#  Row(fromUserId=248, rating=10, toUserId=88546),
#  Row(fromUserId=248, rating=2, toUserId=115827),
#  Row(fromUserId=248, rating=6, toUserId=132578),
#  Row(fromUserId=251, rating=10, toUserId=5747),
#  Row(fromUserId=251, rating=2, toUserId=7886),
#  Row(fromUserId=251, rating=2, toUserId=9366),
#  Row(fromUserId=251, rating=9, toUserId=12509),
#  Row(fromUserId=251, rating=2, toUserId=17685),
#  Row(fromUserId=251, rating=5, toUserId=30652),
#  Row(fromUserId=251, rating=6, toUserId=34450),
#  Row(fromUserId=251, rating=2, toUserId=36489),
#  Row(fromUserId=251, rating=1, toUserId=40632),
#  Row(fromUserId=251, rating=1, toUserId=42213),
#  Row(fromUserId=251, rating=6, toUserId=57582),
#  Row(fromUserId=251, rating=8, toUserId=60025),
#  Row(fromUserId=251, rating=6, toUserId=60622),
#  Row(fromUserId=251, rating=1, toUserId=69587),
#  Row(fromUserId=251, rating=10, toUserId=74263),
#  Row(fromUserId=251, rating=6, toUserId=78387),
#  Row(fromUserId=251, rating=8, toUserId=81373),
#  Row(fromUserId=251, rating=10, toUserId=106805),
#  Row(fromUserId=251, rating=5, toUserId=119769),
#  Row(fromUserId=251, rating=7, toUserId=132024),
#  Row(fromUserId=251, rating=5, toUserId=146675),
#  Row(fromUserId=251, rating=1, toUserId=151491),
#  Row(fromUserId=252, rating=10, toUserId=23145),
#  Row(fromUserId=253, rating=4, toUserId=136732),
#  Row(fromUserId=257, rating=7, toUserId=51400),
#  Row(fromUserId=258, rating=8, toUserId=218007),
#  Row(fromUserId=259, rating=3, toUserId=197901),
#  Row(fromUserId=260, rating=10, toUserId=10148),
#  Row(fromUserId=260, rating=7, toUserId=29503),
#  Row(fromUserId=260, rating=1, toUserId=48636),
#  Row(fromUserId=260, rating=3, toUserId=56675),
#  Row(fromUserId=260, rating=4, toUserId=138374),
#  Row(fromUserId=260, rating=4, toUserId=171906),
#  Row(fromUserId=261, rating=1, toUserId=42472),
#  Row(fromUserId=264, rating=10, toUserId=162736),
#  Row(fromUserId=265, rating=6, toUserId=39203),
#  Row(fromUserId=268, rating=6, toUserId=120092),
#  Row(fromUserId=268, rating=1, toUserId=145403),
#  Row(fromUserId=269, rating=6, toUserId=115737),
#  Row(fromUserId=269, rating=3, toUserId=174199),
#  Row(fromUserId=269, rating=2, toUserId=208964),
#  Row(fromUserId=272, rating=10, toUserId=26193),
#  Row(fromUserId=272, rating=6, toUserId=41978),
#  Row(fromUserId=272, rating=3, toUserId=63237),
#  Row(fromUserId=272, rating=4, toUserId=172917),
#  Row(fromUserId=279, rating=2, toUserId=102486),
#  Row(fromUserId=285, rating=1, toUserId=52225),
#  Row(fromUserId=285, rating=2, toUserId=145692),
#  Row(fromUserId=286, rating=3, toUserId=17752),
#  Row(fromUserId=286, rating=2, toUserId=164798),
#  Row(fromUserId=288, rating=8, toUserId=33658),
#  Row(fromUserId=288, rating=2, toUserId=98678),
#  Row(fromUserId=288, rating=5, toUserId=210718),
#  Row(fromUserId=290, rating=10, toUserId=6437),
#  Row(fromUserId=293, rating=1, toUserId=104544),
#  Row(fromUserId=293, rating=1, toUserId=111394),
#  Row(fromUserId=297, rating=4, toUserId=192666),
#  Row(fromUserId=298, rating=2, toUserId=81133),
#  Row(fromUserId=299, rating=1, toUserId=17049),
#  Row(fromUserId=299, rating=1, toUserId=64774),
#  Row(fromUserId=299, rating=7, toUserId=89548),
#  Row(fromUserId=299, rating=10, toUserId=98678),
#  Row(fromUserId=299, rating=5, toUserId=109149),
#  Row(fromUserId=299, rating=10, toUserId=113794),
#  Row(fromUserId=299, rating=9, toUserId=126293),
#  Row(fromUserId=299, rating=6, toUserId=192735),
#  Row(fromUserId=302, rating=2, toUserId=100711),
#  Row(fromUserId=304, rating=5, toUserId=77323),
#  Row(fromUserId=307, rating=10, toUserId=154003),
#  Row(fromUserId=308, rating=6, toUserId=187656),
#  Row(fromUserId=309, rating=7, toUserId=6932),
#  Row(fromUserId=309, rating=9, toUserId=51868),
#  Row(fromUserId=309, rating=5, toUserId=76231),
#  Row(fromUserId=309, rating=3, toUserId=119879),
#  Row(fromUserId=309, rating=1, toUserId=145571),
#  Row(fromUserId=309, rating=10, toUserId=181820),
#  Row(fromUserId=310, rating=1, toUserId=71042),
#  Row(fromUserId=312, rating=3, toUserId=12195),
#  Row(fromUserId=312, rating=10, toUserId=30166),
#  Row(fromUserId=312, rating=5, toUserId=33710),
#  Row(fromUserId=312, rating=1, toUserId=107547),
#  Row(fromUserId=312, rating=10, toUserId=111557),
#  Row(fromUserId=312, rating=3, toUserId=191657),
#  Row(fromUserId=315, rating=1, toUserId=43702),
#  Row(fromUserId=315, rating=1, toUserId=59495),
#  Row(fromUserId=315, rating=10, toUserId=129037),
#  Row(fromUserId=315, rating=1, toUserId=167167),
#  Row(fromUserId=316, rating=10, toUserId=7692),
#  Row(fromUserId=316, rating=2, toUserId=27728),
#  Row(fromUserId=316, rating=5, toUserId=32667),
#  Row(fromUserId=316, rating=9, toUserId=46378),
#  Row(fromUserId=316, rating=5, toUserId=53948),
#  Row(fromUserId=316, rating=4, toUserId=74795),
#  Row(fromUserId=316, rating=5, toUserId=104821),
#  Row(fromUserId=316, rating=4, toUserId=123119),
#  Row(fromUserId=316, rating=3, toUserId=179226),
#  Row(fromUserId=316, rating=5, toUserId=190097),
#  Row(fromUserId=316, rating=5, toUserId=202993),
#  Row(fromUserId=317, rating=7, toUserId=109101),
#  Row(fromUserId=318, rating=8, toUserId=132449),
#  Row(fromUserId=320, rating=1, toUserId=8609),
#  Row(fromUserId=320, rating=5, toUserId=71588),
#  Row(fromUserId=320, rating=10, toUserId=105647),
#  Row(fromUserId=320, rating=9, toUserId=113542),
#  Row(fromUserId=321, rating=2, toUserId=211977),
#  Row(fromUserId=323, rating=1, toUserId=64257),
#  Row(fromUserId=323, rating=7, toUserId=140553),
#  Row(fromUserId=324, rating=7, toUserId=29733),
#  Row(fromUserId=324, rating=7, toUserId=87624),
#  Row(fromUserId=324, rating=8, toUserId=134406),
#  Row(fromUserId=324, rating=6, toUserId=190483),
#  Row(fromUserId=324, rating=5, toUserId=202543),
#  Row(fromUserId=325, rating=1, toUserId=14199),
#  Row(fromUserId=325, rating=1, toUserId=16466),
#  Row(fromUserId=325, rating=1, toUserId=17558),
#  Row(fromUserId=325, rating=1, toUserId=28812),
#  Row(fromUserId=325, rating=2, toUserId=31302),
#  Row(fromUserId=325, rating=2, toUserId=34797),
#  Row(fromUserId=325, rating=1, toUserId=46216),
#  Row(fromUserId=325, rating=7, toUserId=51043),
#  Row(fromUserId=325, rating=1, toUserId=52748),
#  Row(fromUserId=325, rating=1, toUserId=55619),
#  Row(fromUserId=325, rating=1, toUserId=57642),
#  Row(fromUserId=325, rating=2, toUserId=70751),
#  Row(fromUserId=325, rating=1, toUserId=73810),
#  Row(fromUserId=325, rating=1, toUserId=83238),
#  Row(fromUserId=325, rating=8, toUserId=131613),
#  Row(fromUserId=325, rating=3, toUserId=143947),
#  Row(fromUserId=325, rating=1, toUserId=151518),
#  Row(fromUserId=325, rating=3, toUserId=200826),
#  Row(fromUserId=325, rating=1, toUserId=212841),
#  Row(fromUserId=330, rating=4, toUserId=67751),
#  Row(fromUserId=330, rating=8, toUserId=89543),
#  Row(fromUserId=330, rating=5, toUserId=196566),
#  Row(fromUserId=332, rating=6, toUserId=328),
#  Row(fromUserId=332, rating=6, toUserId=149749),
#  Row(fromUserId=334, rating=1, toUserId=97868),
#  Row(fromUserId=334, rating=1, toUserId=174655),
#  Row(fromUserId=335, rating=5, toUserId=29698),
#  Row(fromUserId=335, rating=1, toUserId=39626),
#  Row(fromUserId=335, rating=4, toUserId=67604),
#  Row(fromUserId=335, rating=2, toUserId=74638),
#  Row(fromUserId=335, rating=4, toUserId=94922),
#  Row(fromUserId=335, rating=1, toUserId=97998),
#  Row(fromUserId=335, rating=1, toUserId=135632),
#  Row(fromUserId=335, rating=1, toUserId=197301),
#  Row(fromUserId=340, rating=10, toUserId=68322),
#  Row(fromUserId=340, rating=10, toUserId=133434),
#  Row(fromUserId=341, rating=10, toUserId=65218),
#  Row(fromUserId=341, rating=10, toUserId=114376),
#  Row(fromUserId=341, rating=9, toUserId=212517),
#  Row(fromUserId=345, rating=1, toUserId=92452),
#  Row(fromUserId=348, rating=8, toUserId=51664),
#  Row(fromUserId=348, rating=5, toUserId=89548),
#  Row(fromUserId=348, rating=7, toUserId=94833),
#  Row(fromUserId=348, rating=1, toUserId=121850),
#  Row(fromUserId=348, rating=1, toUserId=129111),
#  Row(fromUserId=348, rating=2, toUserId=149568),
#  Row(fromUserId=348, rating=5, toUserId=161441),
#  Row(fromUserId=349, rating=10, toUserId=62902),
#  Row(fromUserId=352, rating=8, toUserId=96796),
#  Row(fromUserId=352, rating=7, toUserId=180276),
#  Row(fromUserId=354, rating=5, toUserId=30917),
#  Row(fromUserId=355, rating=10, toUserId=2172),
#  Row(fromUserId=356, rating=6, toUserId=76782),
#  Row(fromUserId=357, rating=8, toUserId=114968),
#  Row(fromUserId=357, rating=9, toUserId=172011),
#  Row(fromUserId=358, rating=5, toUserId=40863),
#  Row(fromUserId=360, rating=8, toUserId=128057),
#  Row(fromUserId=361, rating=5, toUserId=132680),
#  Row(fromUserId=364, rating=2, toUserId=8575),
#  Row(fromUserId=364, rating=5, toUserId=37041),
#  Row(fromUserId=364, rating=2, toUserId=43592),
#  Row(fromUserId=364, rating=9, toUserId=49152),
#  Row(fromUserId=364, rating=1, toUserId=112408),
#  Row(fromUserId=364, rating=1, toUserId=113759),
#  Row(fromUserId=364, rating=1, toUserId=133427),
#  Row(fromUserId=364, rating=7, toUserId=139103),
#  Row(fromUserId=364, rating=4, toUserId=173181),
#  Row(fromUserId=364, rating=2, toUserId=185057),
#  Row(fromUserId=365, rating=3, toUserId=132242),
#  Row(fromUserId=368, rating=5, toUserId=180276),
#  Row(fromUserId=370, rating=10, toUserId=40507),
#  Row(fromUserId=371, rating=5, toUserId=138879),
#  Row(fromUserId=372, rating=4, toUserId=192918),
#  Row(fromUserId=373, rating=10, toUserId=12375),
#  Row(fromUserId=373, rating=6, toUserId=211856),
#  Row(fromUserId=374, rating=7, toUserId=104382),
#  Row(fromUserId=375, rating=2, toUserId=53713),
#  Row(fromUserId=375, rating=7, toUserId=154345),
#  Row(fromUserId=377, rating=10, toUserId=14258),
#  Row(fromUserId=380, rating=1, toUserId=95454),
#  Row(fromUserId=380, rating=8, toUserId=194505),
#  Row(fromUserId=380, rating=9, toUserId=205176),
#  Row(fromUserId=385, rating=1, toUserId=77289),
#  Row(fromUserId=389, rating=4, toUserId=128412),
#  Row(fromUserId=390, rating=1, toUserId=33216),
#  Row(fromUserId=391, rating=10, toUserId=102244),
#  Row(fromUserId=395, rating=7, toUserId=68716),
#  Row(fromUserId=398, rating=3, toUserId=81398),
#  Row(fromUserId=400, rating=4, toUserId=79404),
#  Row(fromUserId=406, rating=7, toUserId=88906),
#  Row(fromUserId=407, rating=10, toUserId=44262),
#  Row(fromUserId=408, rating=10, toUserId=37330),
#  Row(fromUserId=408, rating=6, toUserId=75317),
#  Row(fromUserId=408, rating=8, toUserId=102153),
#  Row(fromUserId=408, rating=9, toUserId=125294),
#  Row(fromUserId=408, rating=8, toUserId=166676),
#  Row(fromUserId=408, rating=6, toUserId=204158),
#  Row(fromUserId=417, rating=8, toUserId=91375),
#  Row(fromUserId=423, rating=6, toUserId=219687),
#  Row(fromUserId=426, rating=8, toUserId=41292),
#  Row(fromUserId=426, rating=5, toUserId=152509),
#  Row(fromUserId=428, rating=1, toUserId=17352),
#  Row(fromUserId=434, rating=10, toUserId=35798),
#  Row(fromUserId=434, rating=10, toUserId=119447),
#  Row(fromUserId=443, rating=10, toUserId=77195),
#  Row(fromUserId=444, rating=7, toUserId=29384),
#  Row(fromUserId=444, rating=6, toUserId=159534),
#  Row(fromUserId=444, rating=1, toUserId=181720),
#  Row(fromUserId=444, rating=6, toUserId=217014),
#  Row(fromUserId=445, rating=3, toUserId=24663),
#  Row(fromUserId=445, rating=2, toUserId=182152),
#  Row(fromUserId=446, rating=8, toUserId=26534),
#  Row(fromUserId=446, rating=6, toUserId=66048),
#  Row(fromUserId=446, rating=2, toUserId=154643),
#  Row(fromUserId=447, rating=8, toUserId=121116),
#  Row(fromUserId=448, rating=1, toUserId=15067),
#  Row(fromUserId=448, rating=10, toUserId=156908),
#  Row(fromUserId=449, rating=10, toUserId=52391),
#  Row(fromUserId=449, rating=7, toUserId=119209),
#  Row(fromUserId=450, rating=1, toUserId=131329),
#  Row(fromUserId=451, rating=10, toUserId=75050),
#  Row(fromUserId=451, rating=6, toUserId=126293),
#  Row(fromUserId=451, rating=7, toUserId=163930),
#  Row(fromUserId=453, rating=6, toUserId=78020),
#  Row(fromUserId=455, rating=2, toUserId=156252),
#  Row(fromUserId=456, rating=1, toUserId=10848),
#  Row(fromUserId=456, rating=5, toUserId=43321),
#  Row(fromUserId=456, rating=1, toUserId=95907),
#  Row(fromUserId=456, rating=1, toUserId=142157),
#  Row(fromUserId=458, rating=3, toUserId=156141),
#  Row(fromUserId=459, rating=8, toUserId=39224),
#  Row(fromUserId=459, rating=6, toUserId=50408),
#  Row(fromUserId=461, rating=3, toUserId=23489),
#  Row(fromUserId=461, rating=5, toUserId=80856),
#  Row(fromUserId=461, rating=10, toUserId=124266),
#  Row(fromUserId=461, rating=5, toUserId=152443),
#  Row(fromUserId=464, rating=10, toUserId=25083),
#  Row(fromUserId=465, rating=5, toUserId=91966),
#  Row(fromUserId=465, rating=10, toUserId=121457),
#  Row(fromUserId=468, rating=10, toUserId=21497),
#  Row(fromUserId=468, rating=6, toUserId=51475),
#  Row(fromUserId=470, rating=10, toUserId=76535),
#  Row(fromUserId=471, rating=6, toUserId=31808),
#  Row(fromUserId=471, rating=6, toUserId=50293),
#  Row(fromUserId=472, rating=8, toUserId=218416),
#  Row(fromUserId=474, rating=10, toUserId=57238),
#  Row(fromUserId=475, rating=10, toUserId=29304),
#  Row(fromUserId=475, rating=10, toUserId=71606),
#  Row(fromUserId=475, rating=8, toUserId=208676),
#  Row(fromUserId=476, rating=1, toUserId=23795),
#  Row(fromUserId=476, rating=8, toUserId=72481),
#  Row(fromUserId=476, rating=1, toUserId=164363),
#  Row(fromUserId=479, rating=10, toUserId=214628),
#  Row(fromUserId=483, rating=9, toUserId=81983),
#  Row(fromUserId=483, rating=7, toUserId=135316),
#  Row(fromUserId=483, rating=1, toUserId=202049),
#  Row(fromUserId=484, rating=10, toUserId=28527),
#  Row(fromUserId=485, rating=10, toUserId=216793),
#  Row(fromUserId=490, rating=7, toUserId=6437),
#  Row(fromUserId=490, rating=5, toUserId=189446),
#  Row(fromUserId=492, rating=8, toUserId=102375),
#  Row(fromUserId=494, rating=7, toUserId=38120),
#  Row(fromUserId=495, rating=10, toUserId=59897),
#  Row(fromUserId=495, rating=4, toUserId=63018),
#  Row(fromUserId=495, rating=5, toUserId=79706),
#  Row(fromUserId=495, rating=10, toUserId=102328),
#  Row(fromUserId=495, rating=10, toUserId=116926),
#  Row(fromUserId=495, rating=7, toUserId=170066),
#  Row(fromUserId=495, rating=1, toUserId=190690),
#  Row(fromUserId=495, rating=1, toUserId=200467),
#  Row(fromUserId=499, rating=10, toUserId=19006),
#  Row(fromUserId=499, rating=3, toUserId=172382),
#  Row(fromUserId=499, rating=8, toUserId=185310),
#  Row(fromUserId=499, rating=4, toUserId=200178),
#  Row(fromUserId=503, rating=10, toUserId=10148),
#  Row(fromUserId=503, rating=4, toUserId=199075),
#  Row(fromUserId=504, rating=9, toUserId=24176),
#  Row(fromUserId=506, rating=2, toUserId=46193),
#  Row(fromUserId=506, rating=1, toUserId=70664),
#  Row(fromUserId=506, rating=7, toUserId=145220),
#  Row(fromUserId=507, rating=7, toUserId=746),
#  Row(fromUserId=511, rating=10, toUserId=66710),
#  Row(fromUserId=512, rating=5, toUserId=98532),
#  Row(fromUserId=513, rating=2, toUserId=3788),
#  Row(fromUserId=513, rating=10, toUserId=13250),
#  Row(fromUserId=513, rating=6, toUserId=17243),
#  Row(fromUserId=513, rating=5, toUserId=19722),
#  Row(fromUserId=513, rating=2, toUserId=29330),
#  Row(fromUserId=513, rating=2, toUserId=37038),
#  Row(fromUserId=513, rating=2, toUserId=60688),
#  Row(fromUserId=513, rating=10, toUserId=68226),
#  Row(fromUserId=513, rating=9, toUserId=69694),
#  Row(fromUserId=513, rating=5, toUserId=74149),
#  Row(fromUserId=513, rating=5, toUserId=103523),
#  Row(fromUserId=513, rating=5, toUserId=117482),
#  Row(fromUserId=513, rating=7, toUserId=124058),
#  Row(fromUserId=513, rating=2, toUserId=144997),
#  Row(fromUserId=513, rating=4, toUserId=148320),
#  Row(fromUserId=513, rating=6, toUserId=210280),
#  Row(fromUserId=514, rating=1, toUserId=95172),
#  Row(fromUserId=516, rating=6, toUserId=6983),
#  Row(fromUserId=518, rating=7, toUserId=67003),
#  Row(fromUserId=518, rating=7, toUserId=100709),
#  Row(fromUserId=518, rating=9, toUserId=110327),
#  Row(fromUserId=518, rating=10, toUserId=118957),
#  Row(fromUserId=518, rating=10, toUserId=132193),
#  Row(fromUserId=520, rating=6, toUserId=29431),
#  Row(fromUserId=520, rating=9, toUserId=41367),
#  Row(fromUserId=520, rating=7, toUserId=61611),
#  Row(fromUserId=520, rating=10, toUserId=80527),
#  Row(fromUserId=520, rating=10, toUserId=86066),
#  Row(fromUserId=520, rating=9, toUserId=112908),
#  Row(fromUserId=520, rating=7, toUserId=123243),
#  Row(fromUserId=520, rating=5, toUserId=128069),
#  Row(fromUserId=520, rating=5, toUserId=176202),
#  Row(fromUserId=520, rating=1, toUserId=178651),
#  Row(fromUserId=520, rating=6, toUserId=190669),
#  Row(fromUserId=524, rating=1, toUserId=56309),
#  Row(fromUserId=531, rating=10, toUserId=9560),
#  Row(fromUserId=532, rating=5, toUserId=41077),
#  Row(fromUserId=536, rating=7, toUserId=84882),
#  Row(fromUserId=536, rating=10, toUserId=106977),
#  Row(fromUserId=536, rating=5, toUserId=109785),
#  Row(fromUserId=536, rating=7, toUserId=122827),
#  Row(fromUserId=536, rating=1, toUserId=158297),
#  Row(fromUserId=536, rating=1, toUserId=167715),
#  Row(fromUserId=537, rating=2, toUserId=9745),
#  Row(fromUserId=538, rating=3, toUserId=52650),
#  Row(fromUserId=539, rating=8, toUserId=12302),
#  Row(fromUserId=541, rating=7, toUserId=77083),
#  Row(fromUserId=541, rating=7, toUserId=137195),
#  Row(fromUserId=541, rating=7, toUserId=151254),
#  Row(fromUserId=542, rating=5, toUserId=125514),
#  Row(fromUserId=543, rating=3, toUserId=123570),
#  Row(fromUserId=544, rating=9, toUserId=14469),
#  Row(fromUserId=544, rating=10, toUserId=117772),
#  Row(fromUserId=545, rating=1, toUserId=5421),
#  Row(fromUserId=545, rating=4, toUserId=53948),
#  Row(fromUserId=545, rating=1, toUserId=97624),
#  Row(fromUserId=545, rating=1, toUserId=117437),
#  Row(fromUserId=545, rating=6, toUserId=124874),
#  Row(fromUserId=545, rating=2, toUserId=135906),
#  Row(fromUserId=549, rating=7, toUserId=6269),
#  Row(fromUserId=549, rating=1, toUserId=36990),
#  Row(fromUserId=549, rating=1, toUserId=53502),
#  Row(fromUserId=549, rating=7, toUserId=84087),
#  Row(fromUserId=549, rating=1, toUserId=106823),
#  Row(fromUserId=549, rating=2, toUserId=114362),
#  Row(fromUserId=549, rating=5, toUserId=195884),
#  Row(fromUserId=550, rating=4, toUserId=19907),
#  Row(fromUserId=550, rating=8, toUserId=105660),
#  Row(fromUserId=551, rating=1, toUserId=28049),
#  Row(fromUserId=551, rating=1, toUserId=52415),
#  Row(fromUserId=551, rating=1, toUserId=107698),
#  Row(fromUserId=551, rating=5, toUserId=146371),
#  Row(fromUserId=553, rating=6, toUserId=483),
#  Row(fromUserId=557, rating=10, toUserId=18074),
#  Row(fromUserId=557, rating=10, toUserId=158622),
#  Row(fromUserId=559, rating=10, toUserId=121859),
#  Row(fromUserId=559, rating=1, toUserId=165332),
#  Row(fromUserId=559, rating=1, toUserId=179932),
#  Row(fromUserId=560, rating=5, toUserId=216835),
#  Row(fromUserId=561, rating=2, toUserId=147713),
#  Row(fromUserId=565, rating=7, toUserId=36964),
#  Row(fromUserId=565, rating=10, toUserId=185982),
#  Row(fromUserId=568, rating=3, toUserId=37709),
#  Row(fromUserId=568, rating=5, toUserId=104252),
#  Row(fromUserId=572, rating=7, toUserId=48734),
#  Row(fromUserId=572, rating=6, toUserId=215403),
#  Row(fromUserId=573, rating=2, toUserId=34557),
#  Row(fromUserId=573, rating=4, toUserId=158054),
#  Row(fromUserId=574, rating=6, toUserId=26924),
#  Row(fromUserId=576, rating=10, toUserId=66455),
#  Row(fromUserId=576, rating=1, toUserId=131757),
#  Row(fromUserId=577, rating=1, toUserId=141339),
#  Row(fromUserId=578, rating=3, toUserId=66478),
#  Row(fromUserId=578, rating=2, toUserId=70324),
#  Row(fromUserId=578, rating=1, toUserId=160917),
#  Row(fromUserId=578, rating=2, toUserId=210400),
#  Row(fromUserId=579, rating=10, toUserId=12425),
#  Row(fromUserId=579, rating=6, toUserId=28557),
#  Row(fromUserId=579, rating=1, toUserId=218685),
#  Row(fromUserId=580, rating=2, toUserId=66686),
#  Row(fromUserId=580, rating=1, toUserId=102328),
#  Row(fromUserId=580, rating=8, toUserId=144792),
#  Row(fromUserId=581, rating=7, toUserId=1616),
#  Row(fromUserId=581, rating=5, toUserId=60464),
#  Row(fromUserId=581, rating=7, toUserId=139019),
#  Row(fromUserId=582, rating=10, toUserId=88427),
#  Row(fromUserId=584, rating=5, toUserId=29098),
#  Row(fromUserId=585, rating=5, toUserId=94922),
#  Row(fromUserId=587, rating=6, toUserId=129427),
#  Row(fromUserId=590, rating=1, toUserId=8296),
#  Row(fromUserId=591, rating=10, toUserId=98678),
#  Row(fromUserId=591, rating=10, toUserId=136822),
#  Row(fromUserId=593, rating=3, toUserId=29125),
#  Row(fromUserId=593, rating=7, toUserId=97929),
#  Row(fromUserId=593, rating=2, toUserId=212635),
#  Row(fromUserId=594, rating=5, toUserId=31378),
#  Row(fromUserId=594, rating=2, toUserId=45541),
#  Row(fromUserId=594, rating=10, toUserId=52246),
#  Row(fromUserId=594, rating=1, toUserId=61246),
#  Row(fromUserId=594, rating=4, toUserId=101395),
#  Row(fromUserId=594, rating=8, toUserId=129663),
#  Row(fromUserId=594, rating=5, toUserId=133691),
#  Row(fromUserId=594, rating=7, toUserId=194042),
#  Row(fromUserId=595, rating=2, toUserId=206555),
#  Row(fromUserId=596, rating=5, toUserId=77826),
#  Row(fromUserId=599, rating=4, toUserId=7625),
#  Row(fromUserId=599, rating=10, toUserId=130970),
#  Row(fromUserId=601, rating=5, toUserId=79835),
#  Row(fromUserId=604, rating=5, toUserId=173744),
#  Row(fromUserId=606, rating=6, toUserId=147295),
#  Row(fromUserId=607, rating=1, toUserId=9852),
#  Row(fromUserId=607, rating=5, toUserId=19277),
#  Row(fromUserId=607, rating=7, toUserId=46052),
#  Row(fromUserId=607, rating=4, toUserId=47525),
#  Row(fromUserId=607, rating=6, toUserId=49650),
#  Row(fromUserId=607, rating=1, toUserId=60834),
#  Row(fromUserId=607, rating=2, toUserId=61934),
#  Row(fromUserId=607, rating=5, toUserId=87207),
#  Row(fromUserId=607, rating=2, toUserId=111718),
#  Row(fromUserId=607, rating=6, toUserId=122965),
#  Row(fromUserId=607, rating=4, toUserId=181202),
#  Row(fromUserId=607, rating=1, toUserId=205870),
#  Row(fromUserId=608, rating=9, toUserId=198031),
#  Row(fromUserId=612, rating=8, toUserId=96428),
#  Row(fromUserId=612, rating=8, toUserId=179893),
#  Row(fromUserId=613, rating=4, toUserId=62082),
#  Row(fromUserId=613, rating=10, toUserId=156148),
#  Row(fromUserId=617, rating=7, toUserId=76725),
#  Row(fromUserId=617, rating=10, toUserId=198845),
#  Row(fromUserId=618, rating=10, toUserId=10531),
#  Row(fromUserId=618, rating=8, toUserId=64570),
#  Row(fromUserId=618, rating=9, toUserId=99219),
#  Row(fromUserId=618, rating=8, toUserId=174163),
#  Row(fromUserId=619, rating=10, toUserId=137372),
#  Row(fromUserId=620, rating=6, toUserId=108041),
#  Row(fromUserId=621, rating=2, toUserId=184349),
#  Row(fromUserId=622, rating=8, toUserId=83257),
#  Row(fromUserId=623, rating=6, toUserId=13140),
#  Row(fromUserId=623, rating=7, toUserId=45008),
#  Row(fromUserId=623, rating=10, toUserId=50327),
#  Row(fromUserId=623, rating=3, toUserId=52621),
#  Row(fromUserId=623, rating=2, toUserId=90124),
#  Row(fromUserId=623, rating=10, toUserId=104633),
#  Row(fromUserId=623, rating=5, toUserId=176653),
#  Row(fromUserId=625, rating=5, toUserId=163100),
#  Row(fromUserId=627, rating=5, toUserId=40547),
#  Row(fromUserId=628, rating=1, toUserId=87069),
#  Row(fromUserId=629, rating=6, toUserId=77562),
#  Row(fromUserId=629, rating=8, toUserId=104785),
#  Row(fromUserId=630, rating=9, toUserId=51868),
#  Row(fromUserId=630, rating=5, toUserId=163933),
#  Row(fromUserId=630, rating=7, toUserId=194553),
#  Row(fromUserId=633, rating=4, toUserId=24309),
#  Row(fromUserId=634, rating=9, toUserId=118066),
#  Row(fromUserId=636, rating=10, toUserId=57594),
#  Row(fromUserId=646, rating=10, toUserId=96155),
#  Row(fromUserId=646, rating=4, toUserId=123485),
#  Row(fromUserId=646, rating=9, toUserId=201890),
#  Row(fromUserId=647, rating=10, toUserId=85862),
#  Row(fromUserId=649, rating=6, toUserId=70913),
#  Row(fromUserId=649, rating=10, toUserId=99476),
#  Row(fromUserId=649, rating=10, toUserId=164042),
#  Row(fromUserId=650, rating=8, toUserId=139330),
#  Row(fromUserId=651, rating=6, toUserId=83773),
#  Row(fromUserId=651, rating=5, toUserId=153452),
#  Row(fromUserId=651, rating=3, toUserId=202715),
#  Row(fromUserId=652, rating=4, toUserId=144414),
#  Row(fromUserId=653, rating=10, toUserId=36793),
#  Row(fromUserId=658, rating=7, toUserId=20539),
#  Row(fromUserId=661, rating=5, toUserId=157134),
#  Row(fromUserId=664, rating=4, toUserId=39394),
#  Row(fromUserId=664, rating=9, toUserId=121590),
#  Row(fromUserId=664, rating=8, toUserId=155084),
#  Row(fromUserId=664, rating=6, toUserId=181036),
#  Row(fromUserId=666, rating=1, toUserId=57047),
#  Row(fromUserId=667, rating=7, toUserId=50216),
#  Row(fromUserId=668, rating=9, toUserId=213767),
#  Row(fromUserId=669, rating=10, toUserId=84895),
#  Row(fromUserId=670, rating=1, toUserId=21365),
#  Row(fromUserId=670, rating=5, toUserId=73067),
#  Row(fromUserId=670, rating=10, toUserId=89572),
#  Row(fromUserId=670, rating=8, toUserId=100142),
#  Row(fromUserId=670, rating=10, toUserId=101477),
#  Row(fromUserId=670, rating=1, toUserId=120140),
#  Row(fromUserId=670, rating=2, toUserId=138027),
#  Row(fromUserId=670, rating=5, toUserId=170730),
#  Row(fromUserId=670, rating=5, toUserId=214939),
#  Row(fromUserId=672, rating=1, toUserId=63003),
#  Row(fromUserId=672, rating=5, toUserId=88593),
#  Row(fromUserId=672, rating=7, toUserId=123492),
#  Row(fromUserId=672, rating=1, toUserId=203790),
#  Row(fromUserId=672, rating=1, toUserId=217087),
#  Row(fromUserId=673, rating=10, toUserId=201280),
#  Row(fromUserId=675, rating=10, toUserId=11282),
#  Row(fromUserId=675, rating=5, toUserId=24899),
#  Row(fromUserId=675, rating=5, toUserId=27075),
#  Row(fromUserId=675, rating=9, toUserId=50412),
#  Row(fromUserId=675, rating=10, toUserId=54984),
#  Row(fromUserId=675, rating=7, toUserId=59543),
#  Row(fromUserId=675, rating=10, toUserId=60712),
#  Row(fromUserId=675, rating=7, toUserId=61646),
#  Row(fromUserId=675, rating=10, toUserId=80309),
#  Row(fromUserId=675, rating=2, toUserId=96278),
#  Row(fromUserId=675, rating=3, toUserId=104343),
#  Row(fromUserId=675, rating=10, toUserId=119193),
#  Row(fromUserId=675, rating=1, toUserId=150874),
#  Row(fromUserId=675, rating=3, toUserId=156075),
#  Row(fromUserId=675, rating=4, toUserId=157304),
#  Row(fromUserId=675, rating=10, toUserId=182465),
#  Row(fromUserId=675, rating=1, toUserId=215167),
#  Row(fromUserId=679, rating=10, toUserId=60197),
#  Row(fromUserId=679, rating=10, toUserId=88269),
#  Row(fromUserId=679, rating=10, toUserId=175266),
#  Row(fromUserId=690, rating=1, toUserId=29060),
#  Row(fromUserId=690, rating=5, toUserId=112826),
#  Row(fromUserId=690, rating=1, toUserId=188490),
#  Row(fromUserId=691, rating=6, toUserId=96145),
#  Row(fromUserId=693, rating=1, toUserId=110041),
#  Row(fromUserId=695, rating=6, toUserId=140174),
#  Row(fromUserId=701, rating=2, toUserId=170196),
#  Row(fromUserId=702, rating=1, toUserId=114857),
#  Row(fromUserId=702, rating=6, toUserId=152675),
#  Row(fromUserId=703, rating=4, toUserId=13928),
#  Row(fromUserId=703, rating=9, toUserId=18691),
#  Row(fromUserId=703, rating=9, toUserId=23645),
#  Row(fromUserId=703, rating=3, toUserId=29603),
#  Row(fromUserId=703, rating=10, toUserId=31754),
#  Row(fromUserId=703, rating=6, toUserId=56383),
#  Row(fromUserId=703, rating=5, toUserId=105673),
#  Row(fromUserId=703, rating=1, toUserId=118153),
#  Row(fromUserId=703, rating=7, toUserId=129017),
#  Row(fromUserId=703, rating=7, toUserId=146313),
#  Row(fromUserId=703, rating=2, toUserId=214346),
#  Row(fromUserId=704, rating=8, toUserId=40998),
#  Row(fromUserId=704, rating=5, toUserId=70522),
#  Row(fromUserId=704, rating=8, toUserId=126189),
#  Row(fromUserId=704, rating=6, toUserId=188504),
#  Row(fromUserId=705, rating=10, toUserId=95937),
#  Row(fromUserId=705, rating=2, toUserId=150789),
#  Row(fromUserId=706, rating=6, toUserId=45992),
#  Row(fromUserId=707, rating=2, toUserId=163889),
#  Row(fromUserId=708, rating=10, toUserId=53614),
#  Row(fromUserId=709, rating=10, toUserId=93681),
#  Row(fromUserId=710, rating=6, toUserId=25320),
#  Row(fromUserId=710, rating=10, toUserId=83846),
#  Row(fromUserId=710, rating=10, toUserId=159164),
#  Row(fromUserId=712, rating=3, toUserId=46833),
#  Row(fromUserId=716, rating=10, toUserId=4538),
#  Row(fromUserId=716, rating=3, toUserId=191522),
#  Row(fromUserId=717, rating=5, toUserId=84814),
#  Row(fromUserId=719, rating=3, toUserId=71740),
#  Row(fromUserId=719, rating=1, toUserId=137550),
#  Row(fromUserId=720, rating=10, toUserId=2928),
#  Row(fromUserId=720, rating=6, toUserId=23390),
#  Row(fromUserId=720, rating=7, toUserId=29709),
#  Row(fromUserId=720, rating=10, toUserId=31527),
#  Row(fromUserId=720, rating=3, toUserId=33119),
#  Row(fromUserId=720, rating=9, toUserId=54003),
#  Row(fromUserId=720, rating=8, toUserId=58476),
#  Row(fromUserId=720, rating=9, toUserId=61741),
#  Row(fromUserId=720, rating=10, toUserId=127904),
#  Row(fromUserId=720, rating=7, toUserId=129860),
#  Row(fromUserId=720, rating=10, toUserId=132669),
#  Row(fromUserId=720, rating=10, toUserId=133748),
#  Row(fromUserId=720, rating=8, toUserId=134340),
#  Row(fromUserId=720, rating=9, toUserId=136641),
#  Row(fromUserId=720, rating=5, toUserId=141319),
#  Row(fromUserId=720, rating=9, toUserId=183753),
#  Row(fromUserId=721, rating=7, toUserId=64834),
#  Row(fromUserId=724, rating=8, toUserId=72481),
#  Row(fromUserId=725, rating=8, toUserId=130815),
#  Row(fromUserId=726, rating=7, toUserId=32980),
#  Row(fromUserId=727, rating=10, toUserId=130970),
#  Row(fromUserId=728, rating=6, toUserId=82260),
#  Row(fromUserId=729, rating=1, toUserId=478),
#  Row(fromUserId=729, rating=1, toUserId=17893),
#  Row(fromUserId=729, rating=6, toUserId=52659),
#  Row(fromUserId=729, rating=4, toUserId=85394),
#  Row(fromUserId=729, rating=3, toUserId=89469),
#  Row(fromUserId=729, rating=4, toUserId=91883),
#  Row(fromUserId=729, rating=6, toUserId=96028),
#  Row(fromUserId=729, rating=1, toUserId=117936),
#  Row(fromUserId=729, rating=4, toUserId=175520),
#  Row(fromUserId=730, rating=1, toUserId=1123),
#  Row(fromUserId=730, rating=5, toUserId=21079),
#  Row(fromUserId=730, rating=4, toUserId=37353),
#  Row(fromUserId=730, rating=1, toUserId=48053),
#  Row(fromUserId=730, rating=1, toUserId=54007),
#  Row(fromUserId=730, rating=6, toUserId=95988),
#  Row(fromUserId=730, rating=7, toUserId=107776),
#  Row(fromUserId=730, rating=5, toUserId=115476),
#  Row(fromUserId=730, rating=1, toUserId=119973),
#  Row(fromUserId=730, rating=4, toUserId=122284),
#  Row(fromUserId=730, rating=5, toUserId=149193),
#  Row(fromUserId=730, rating=1, toUserId=164363),
#  Row(fromUserId=730, rating=10, toUserId=196107),
#  Row(fromUserId=732, rating=10, toUserId=75050),
#  Row(fromUserId=735, rating=1, toUserId=204185),
#  Row(fromUserId=736, rating=3, toUserId=146735),
#  Row(fromUserId=736, rating=6, toUserId=201897),
#  Row(fromUserId=737, rating=7, toUserId=110108),
#  Row(fromUserId=737, rating=5, toUserId=125273),
#  Row(fromUserId=737, rating=6, toUserId=177905),
#  Row(fromUserId=739, rating=10, toUserId=105470),
#  Row(fromUserId=739, rating=6, toUserId=213383),
#  Row(fromUserId=742, rating=3, toUserId=6847),
#  Row(fromUserId=742, rating=8, toUserId=36572),
#  Row(fromUserId=742, rating=10, toUserId=67388),
#  Row(fromUserId=742, rating=2, toUserId=184349),
#  Row(fromUserId=742, rating=1, toUserId=199711),
#  Row(fromUserId=744, rating=10, toUserId=22670),
#  Row(fromUserId=744, rating=1, toUserId=41828),
#  Row(fromUserId=744, rating=7, toUserId=126115),
#  Row(fromUserId=745, rating=1, toUserId=119086),
#  Row(fromUserId=746, rating=2, toUserId=18987),
#  Row(fromUserId=752, rating=10, toUserId=86664),
#  Row(fromUserId=756, rating=9, toUserId=44107),
#  Row(fromUserId=757, rating=10, toUserId=18685),
#  Row(fromUserId=757, rating=9, toUserId=21872),
#  Row(fromUserId=757, rating=10, toUserId=27918),
#  Row(fromUserId=757, rating=5, toUserId=30738),
#  Row(fromUserId=757, rating=10, toUserId=49494),
#  Row(fromUserId=757, rating=6, toUserId=50350),
#  Row(fromUserId=757, rating=10, toUserId=58102),
#  Row(fromUserId=757, rating=10, toUserId=71865),
#  Row(fromUserId=757, rating=6, toUserId=83475),
#  Row(fromUserId=757, rating=10, toUserId=86091),
#  Row(fromUserId=757, rating=9, toUserId=87018),
#  Row(fromUserId=757, rating=9, toUserId=102609),
#  Row(fromUserId=757, rating=2, toUserId=108422),
#  Row(fromUserId=757, rating=7, toUserId=121318),
#  Row(fromUserId=757, rating=8, toUserId=164881),
#  Row(fromUserId=757, rating=2, toUserId=195268),
#  Row(fromUserId=757, rating=7, toUserId=200450),
#  Row(fromUserId=757, rating=10, toUserId=220517),
#  Row(fromUserId=762, rating=9, toUserId=34856),
#  Row(fromUserId=762, rating=8, toUserId=40998),
#  Row(fromUserId=762, rating=1, toUserId=71673),
#  Row(fromUserId=762, rating=9, toUserId=86777),
#  Row(fromUserId=762, rating=5, toUserId=199266),
#  Row(fromUserId=763, rating=10, toUserId=65602),
#  Row(fromUserId=764, rating=10, toUserId=69603),
#  Row(fromUserId=764, rating=6, toUserId=86091),
#  Row(fromUserId=764, rating=8, toUserId=120239),
#  Row(fromUserId=764, rating=7, toUserId=168905),
#  Row(fromUserId=765, rating=10, toUserId=143717),
#  Row(fromUserId=765, rating=9, toUserId=158872),
#  Row(fromUserId=769, rating=8, toUserId=104944),
#  Row(fromUserId=769, rating=10, toUserId=204987),
#  Row(fromUserId=770, rating=5, toUserId=25731),
#  Row(fromUserId=770, rating=6, toUserId=103905),
#  Row(fromUserId=771, rating=1, toUserId=24309),
#  Row(fromUserId=771, rating=3, toUserId=110261),
#  Row(fromUserId=775, rating=10, toUserId=68797),
#  Row(fromUserId=780, rating=6, toUserId=113106),
#  Row(fromUserId=780, rating=10, toUserId=156694),
#  Row(fromUserId=781, rating=1, toUserId=14888),
#  Row(fromUserId=781, rating=3, toUserId=102981),
#  Row(fromUserId=781, rating=9, toUserId=119927),
#  Row(fromUserId=781, rating=4, toUserId=173551),
#  Row(fromUserId=783, rating=5, toUserId=39550),
#  Row(fromUserId=783, rating=4, toUserId=122189),
#  Row(fromUserId=783, rating=2, toUserId=184735),
#  Row(fromUserId=785, rating=10, toUserId=91997),
#  Row(fromUserId=785, rating=5, toUserId=209161),
#  Row(fromUserId=787, rating=5, toUserId=53967),
#  Row(fromUserId=788, rating=8, toUserId=20108),
#  Row(fromUserId=788, rating=9, toUserId=93172),
#  Row(fromUserId=789, rating=4, toUserId=25934),
#  Row(fromUserId=793, rating=4, toUserId=2267),
#  Row(fromUserId=794, rating=1, toUserId=37713),
#  Row(fromUserId=794, rating=1, toUserId=131467),
#  Row(fromUserId=795, rating=5, toUserId=33784),
#  Row(fromUserId=796, rating=4, toUserId=19961),
#  Row(fromUserId=796, rating=6, toUserId=74629),
#  Row(fromUserId=796, rating=10, toUserId=207002),
#  Row(fromUserId=797, rating=3, toUserId=149185),
#  Row(fromUserId=798, rating=9, toUserId=202891),
#  ...]

# %% [markdown]
# # Next Steps

# %% [markdown]
# Here are some further questions to get to grips with Spark DataFrames.

# %% [markdown]
# ### Task 1: Who are the top 5 users that gives the highest average rating of other profiles?

# %%
mostActiveUsersSchemaDF = ratingsJson_DF.select("fromUserId", "rating")\
                                        .groupBy("fromUserId")\
                                        .avg("rating")\
                                        .withColumnRenamed("AVG(rating)", "avg_rating")\
                                        .orderBy(["avg_rating"], ascending=[0])
mostActiveUsersSchemaDF.take(5)
# Out:
# [Row(fromUserId=8294, avg_rating=9.973045822102426),
#  Row(fromUserId=50518, avg_rating=9.966666666666667),
#  Row(fromUserId=134609, avg_rating=9.95),
#  Row(fromUserId=60129, avg_rating=9.87719298245614),
#  Row(fromUserId=63150, avg_rating=9.873417721518987)]

# %% [markdown]
# ### Task 2: How many pairs of users have rated each other with a rating > 5?

# %%
t1 = ratingsJson_DF.alias("t1")
t2 = ratingsJson_DF.withColumnRenamed("fromUserId", "f")\
                   .withColumnRenamed("toUserId", "t")\
                   .withColumnRenamed("rating", "r")\
                   .alias("t2")
cond = (t1.fromUserId == t2.t) & (t1.toUserId == t2.f) & (t1.rating > 5) & (t2.r > 5)
matchesDF = t1.join(t2, cond)
matchesDF.take(10)
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-9-5c5525b11d35> in <module>()
#       3 cond = (t1.fromUserId == t2.t) & (t1.toUserId == t2.f) & (t1.rating > 5) & (t2.r > 5)
#       4 matchesDF = t1.join(t2, cond)
# ----> 5 matchesDF.take(10)
#
# /usr/local/spark/python/pyspark/sql/dataframe.pyc in take(self, num)
#     304         with SCCallSiteSync(self._sc) as css:
#     305             port = self._sc._jvm.org.apache.spark.sql.execution.EvaluatePython.takeAndServe(
# --> 306                 self._jdf, num)
#     307         return list(_load_from_socket(port, BatchedSerializer(PickleSerializer())))
#     308
#
# /usr/local/spark/python/lib/py4j-0.9-src.zip/py4j/java_gateway.py in __call__(self, *args)
#     811         answer = self.gateway_client.send_command(command)
#     812         return_value = get_return_value(
# --> 813             answer, self.gateway_client, self.target_id, self.name)
#     814
#     815         for temp_arg in temp_args:
#
# /usr/local/spark/python/pyspark/sql/utils.pyc in deco(*a, **kw)
#      43     def deco(*a, **kw):
#      44         try:
# ---> 45             return f(*a, **kw)
#      46         except py4j.protocol.Py4JJavaError as e:
#      47             s = e.java_exception.toString()
#
# /usr/local/spark/python/lib/py4j-0.9-src.zip/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     306                 raise Py4JJavaError(
#     307                     "An error occurred while calling {0}{1}{2}.\n".
# --> 308                     format(target_id, ".", name), value)
#     309             else:
#     310                 raise Py4JError(
#
# Py4JJavaError: An error occurred while calling z:org.apache.spark.sql.execution.EvaluatePython.takeAndServe.
# : org.apache.spark.SparkException: Job aborted due to stage failure: Task 6 in stage 22.0 failed 4 times, most recent failure: Lost task 6.3 in stage 22.0 (TID 875, ip-172-31-34-107.us-west-2.compute.internal): java.io.FileNotFoundException: /tmp/spark-86a637c6-354d-4f08-81c1-a4af3c861cbc/executor-6474d8c2-34e1-460c-9ec4-e89e4476631d/blockmgr-4b3ec72c-e70c-43a0-9d35-610e8b9ae830/10/temp_shuffle_08d02f13-5114-4293-9892-45122b4f63a4 (Too many open files)
# 	at java.io.FileOutputStream.open(Native Method)
# 	at java.io.FileOutputStream.<init>(FileOutputStream.java:221)
# 	at org.apache.spark.storage.DiskBlockObjectWriter.open(DiskBlockObjectWriter.scala:88)
# 	at org.apache.spark.shuffle.sort.BypassMergeSortShuffleWriter.write(BypassMergeSortShuffleWriter.java:140)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:73)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:41)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:89)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:214)
# 	at java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1145)
# 	at java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:615)
# 	at java.lang.Thread.run(Thread.java:745)
#
# Driver stacktrace:
# 	at org.apache.spark.scheduler.DAGScheduler.org$apache$spark$scheduler$DAGScheduler$$failJobAndIndependentStages(DAGScheduler.scala:1431)
# 	at org.apache.spark.scheduler.DAGScheduler$$anonfun$abortStage$1.apply(DAGScheduler.scala:1419)
# 	at org.apache.spark.scheduler.DAGScheduler$$anonfun$abortStage$1.apply(DAGScheduler.scala:1418)
# 	at scala.collection.mutable.ResizableArray$class.foreach(ResizableArray.scala:59)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:47)
# 	at org.apache.spark.scheduler.DAGScheduler.abortStage(DAGScheduler.scala:1418)
# 	at org.apache.spark.scheduler.DAGScheduler$$anonfun$handleTaskSetFailed$1.apply(DAGScheduler.scala:799)
# 	at org.apache.spark.scheduler.DAGScheduler$$anonfun$handleTaskSetFailed$1.apply(DAGScheduler.scala:799)
# 	at scala.Option.foreach(Option.scala:236)
# 	at org.apache.spark.scheduler.DAGScheduler.handleTaskSetFailed(DAGScheduler.scala:799)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.doOnReceive(DAGScheduler.scala:1640)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.onReceive(DAGScheduler.scala:1599)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.onReceive(DAGScheduler.scala:1588)
# 	at org.apache.spark.util.EventLoop$$anon$1.run(EventLoop.scala:48)
# 	at org.apache.spark.scheduler.DAGScheduler.runJob(DAGScheduler.scala:620)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:1832)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:1845)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:1858)
# 	at org.apache.spark.sql.execution.SparkPlan.executeTake(SparkPlan.scala:212)
# 	at org.apache.spark.sql.execution.EvaluatePython$$anonfun$takeAndServe$1.apply$mcI$sp(python.scala:126)
# 	at org.apache.spark.sql.execution.EvaluatePython$$anonfun$takeAndServe$1.apply(python.scala:124)
# 	at org.apache.spark.sql.execution.EvaluatePython$$anonfun$takeAndServe$1.apply(python.scala:124)
# 	at org.apache.spark.sql.execution.SQLExecution$.withNewExecutionId(SQLExecution.scala:56)
# 	at org.apache.spark.sql.DataFrame.withNewExecutionId(DataFrame.scala:2086)
# 	at org.apache.spark.sql.execution.EvaluatePython$.takeAndServe(python.scala:124)
# 	at org.apache.spark.sql.execution.EvaluatePython.takeAndServe(python.scala)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:57)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:606)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:231)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:381)
# 	at py4j.Gateway.invoke(Gateway.java:259)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:133)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:209)
# 	at java.lang.Thread.run(Thread.java:745)
# Caused by: java.io.FileNotFoundException: /tmp/spark-86a637c6-354d-4f08-81c1-a4af3c861cbc/executor-6474d8c2-34e1-460c-9ec4-e89e4476631d/blockmgr-4b3ec72c-e70c-43a0-9d35-610e8b9ae830/10/temp_shuffle_08d02f13-5114-4293-9892-45122b4f63a4 (Too many open files)
# 	at java.io.FileOutputStream.open(Native Method)
# 	at java.io.FileOutputStream.<init>(FileOutputStream.java:221)
# 	at org.apache.spark.storage.DiskBlockObjectWriter.open(DiskBlockObjectWriter.scala:88)
# 	at org.apache.spark.shuffle.sort.BypassMergeSortShuffleWriter.write(BypassMergeSortShuffleWriter.java:140)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:73)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:41)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:89)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:214)
# 	at java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1145)
# 	at java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:615)
# 	... 1 more

# %%
print "{} pairs of users".format(matchesDF.count())
